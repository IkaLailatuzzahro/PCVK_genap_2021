# %% [markdown]
# <a href="https://colab.research.google.com/github/IkaLailatuzzahro/PCVK_genap_2021/blob/main/TugasWeek2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive


# Accrssing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/pcvk/kitten01.jpg')
plt.imshow(img)

# %%
imgt = img
imgt[:,:,0] = np.zeros([imgt.shape[0], imgt.shape[1]])
plt.imshow(imgt)

# %%
imgt1 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
imgt1[:,:,2] = np.zeros([imgt1.shape[0], imgt1.shape[1]])
plt.imshow(imgt1)
